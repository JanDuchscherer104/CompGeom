# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from qhull_analyzer import QhullAnalyzerConfig
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
config = QhullAnalyzerConfig(
    num_points=sorted([j * 10 ** i for j in (1, 2, 5) for i in range(1,9)])
)
experiment = config.setup()

# %%
df = experiment.run()
df.info()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = experiment.run()
#       2 df.info()
#
# File ~/repos/CompGeom/lab04/qhull_analyzer/qhull_analyzer/qhull.py:136, in Experiment.run(self)
#     134 params_df = self.config.generate_params()
#     135 if self.config.is_parallel:
# --> 136     results = params_df.parallel_apply(self._worker, axis=1)
#     137     for result in results:
#     138         self.runtime_tracker.add_runtime(*result)
#
# File ~/miniconda3/envs/comp-geom/lib/python3.12/site-packages/pandarallel/core.py:307, in parallelize_with_memory_file_system.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     299 generation = count()
#     301 while any(
#     302     (
#     303         worker_status == WorkerStatus.Running
# ...

# %%
df.head()
# Out:
#    dimensions  num_points   runtime rbox_options qhull_options
# 0           2          10  0.001568         c D2      -V Qv Qt
# 1           2          10  0.001314         c D2      -V Qv QJ
# 2           2          10  0.001768         c D2      -V Qv Tv
# 3           2          20  0.002095         c D2      -V Qv Qt
# 4           2          20  0.001661         c D2      -V Qv QJ

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df,
    x="num_points",
    y="runtime",
    hue="rbox_options",
    # style="qhull_options",
    markers=True,
    dashes=False,
)
# plt.yscale("log")
plt.xscale("log")
plt.title("Qhull Runtime Analysis")
plt.xlabel("Number of Points")
plt.ylabel("Runtime (seconds)")
plt.legend(title="Dimensions")
plt.show()
